# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\shubham_kumar\\Desktop\\HistoricalQuotes.csv",parse_dates=["Date"],index_col="Date")
df
# Out:
#             Close/Last    Volume      Open       High         Low
# Date
# 2019-11-29     $267.25  11654360    $266.6       $268      $265.9
# 2019-11-27     $267.84  16386120   $265.58    $267.98     $265.31
# 2019-11-26     $264.29  26334880   $266.94    $267.16      $262.5
# 2019-11-25     $266.37  21029520   $262.71    $266.44     $262.52
# 2019-11-22     $261.78  16331260   $262.59    $263.18     $260.84
# 2019-11-21     $262.01  30348780   $263.69   $264.005     $261.18
# 2019-11-20     $263.19  26609920   $265.54   $266.083      $260.4
# 2019-11-19     $266.29  19069600    $267.9       $268   $265.3926
# 2019-11-18      $267.1  21700900    $265.8    $267.43     $264.23
# 2019-11-15     $265.76  25093670   $263.68    $265.78     $263.01
# 2019-11-14     $262.64  22395560   $263.75    $264.88      $262.1
# 2019-11-13     $264.47  25817590   $261.13    $264.78     $261.07
# 2019-11-12     $261.96  21847230   $261.55    $262.79     $260.92
# 2019-11-11      $262.2  20507460    $258.3    $262.47     $258.28
# 2019-11-08     $260.14  17520500   $258.69    $260.44     $256.85
# 2019-11-07     $259.43  23735080   $258.74    $260.35     $258.11
# 2019-11-06     $257.24  18966120   $256.77    $257.49    $255.365
# 2019-11-05     $257.13  19974430   $257.05    $258.19     $256.32
# 2019-11-04      $257.5  25817950   $257.33   $257.845     $255.38

# %%
df["2019-11-13":"2019-11-11"]
# Out:
#             Close/Last    Volume      Open      High       Low
# Date
# 2019-11-13     $264.47  25817590   $261.13   $264.78   $261.07
# 2019-11-12     $261.96  21847230   $261.55   $262.79   $260.92
# 2019-11-11      $262.2  20507460    $258.3   $262.47   $258.28

# %%
# %matplotlib inline
df.plot()

# %%
#generate frequency 
df=pd.date_range(start="08/11/2019",periods=20,freq='B')
df
# Out:
# DatetimeIndex(['2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', freq='B')
